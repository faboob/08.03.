# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df_tips = sns.load_dataset('tips')
print(df_tips.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
sns.barplot(x = 'day', y = 'total_bill', data = df_tips, hue = 'smoker', color='grey', )
# Out:
# /var/folders/s3/j544kzd102j71vn2fqs0lk_r0000gn/T/ipykernel_46572/3589886864.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:grey'` for the same effect.
#
#   sns.barplot(x = 'day', y = 'total_bill', data = df_tips, hue = 'smoker', color='grey', )
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = 'day', y = 'total_bill', data = df_tips, hue = 'smoker', color='grey')
sns.despine(left = 'True')
# Out:
# /var/folders/s3/j544kzd102j71vn2fqs0lk_r0000gn/T/ipykernel_46572/3559631776.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:grey'` for the same effect.
#
#   sns.barplot(x = 'day', y = 'total_bill', data = df_tips, hue = 'smoker', color='grey')
